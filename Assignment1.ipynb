# %% [markdown]
# 1. Read the dataset to python environment

# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\Radhika K J\Downloads\iris_excel.csv")

# %%
dataset
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 2. Display the columns in the dataset.

# %%
dataset.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ## 3. Calculate the mean of each column of the dataset.

# %%
dataset.mean()
# Out:
# C:\Users\Radhika K J\AppData\Local\Temp\ipykernel_72340\1799472221.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4. Check for the null values present in the dataset.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# 5. Perform meaningful visualizations using the dataset.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.barh(dataset['SL'],dataset['SW'], color='red')
plt.figure(figsize=(20,23))
plt.title('Bar Graph')
plt.xlabel('SL')
plt.ylabel('SW')
plt.show()

# %%
data1= dataset.set_index('SW')
dataset['SW'] .plot.pie()
plt.figure(figsize=(23,6))

# %%
plt.boxplot(dataset['SL'])
plt.show()

# %%
corr_matrix = dataset.corr()
sns.heatmap(corr_matrix,annot=True,cmap="PiYG")
# Out:
# C:\Users\Radhika K J\AppData\Local\Temp\ipykernel_72340\2203901504.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = dataset.corr()
# <Axes: >
